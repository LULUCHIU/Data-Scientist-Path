# %%
import pandas as pd
import numpy as np
df = pd.read_excel("../@data/clinic_clean_use2.xlsx")
df.head()
# Out:
#         day        Sample ID   Age     Stage  Genome Altered Histologic Grade  \
# 0  1/1/2020  TCGA-2V-A95S-01   NaN  STAGE II          0.2041               G3
# 1  1/2/2020  TCGA-2Y-A9GS-01  58.0  STAGE IV          0.3002               G2
# 2  1/1/2021  TCGA-2Y-A9GT-01  51.0   STAGE I          0.0622              NaN
# 3  1/2/2021  TCGA-2Y-A9GU-01  55.0   STAGE I          0.3157              NaN
# 4  1/1/2022  TCGA-2Y-A9GV-01  54.0   STAGE I          0.0928               G1
#
#    MSIMANTIS Score  MSIsensor Score  Mutation Count New Neoplasm Event  \
# 0           0.3003              NaN            85.0                NaN
# 1           0.3208              NaN            65.0                Yes
# 2           0.3119             0.02            84.0                Yes
# 3           0.3194             0.09           138.0                 No
# 4           0.2977             0.03             NaN                Yes
#
#   Radiation Therapy     Sex  Weight
# ...

# %%
df.columns
# Out:
# Index(['day', 'Sample ID', 'Age', 'Stage', 'Genome Altered',
#        'Histologic Grade', 'MSIMANTIS Score', 'MSIsensor Score',
#        'Mutation Count', 'New Neoplasm Event', 'Radiation Therapy', 'Sex',
#        'Weight'],
#       dtype='object')

# %%
df = df.sort_values(by=['MSIMANTIS Score','Mutation Count','Genome Altered'],ascending=True)
df
# Out:
#          day        Sample ID   Age      Stage  Genome Altered  \
# 4   1/1/2022  TCGA-2Y-A9GV-01  54.0    STAGE I          0.0928
# 0   1/1/2020  TCGA-2V-A95S-01   NaN   STAGE II          0.2041
# 5   1/2/2022  TCGA-2Y-A9GW-01  64.0    STAGE I          0.1478
# 9   1/2/2024  TCGA-2Y-A9H0-01  49.0  STAGE III          0.2037
# 15  1/2/2027  TCGA-2Y-A9H6-01  68.0    STAGE I          0.2319
# 10  1/1/2025  TCGA-2Y-A9H1-01  58.0    STAGE I          0.1707
# 14  1/1/2027  TCGA-2Y-A9H5-01  59.0    STAGE I             NaN
# 12  1/1/2026  TCGA-2Y-A9H3-01  45.0   STAGE II          0.1642
# 2   1/1/2021  TCGA-2Y-A9GT-01  51.0    STAGE I          0.0622
# 13  1/2/2026  TCGA-2Y-A9H4-01  68.0    STAGE I          0.2580
# 6   1/1/2023  TCGA-2Y-A9GX-01  68.0    STAGE I          0.0122
# 8   1/1/2024  TCGA-2Y-A9GZ-01  82.0   STAGE II          0.4572
# 18  1/1/2029  TCGA-2Y-A9H9-01  70.0    STAGE I             NaN
# 17  1/2/2028  TCGA-2Y-A9H8-01  85.0   STAGE II          0.5459
# ...

# %%
df.interpolate(method='linear')
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_7751/1321276365.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear')
#          day        Sample ID   Age      Stage  Genome Altered  \
# 4   1/1/2022  TCGA-2Y-A9GV-01  54.0    STAGE I         0.09280
# 0   1/1/2020  TCGA-2V-A95S-01  59.0   STAGE II         0.20410
# 5   1/2/2022  TCGA-2Y-A9GW-01  64.0    STAGE I         0.14780
# 9   1/2/2024  TCGA-2Y-A9H0-01  49.0  STAGE III         0.20370
# 15  1/2/2027  TCGA-2Y-A9H6-01  68.0    STAGE I         0.23190
# 10  1/1/2025  TCGA-2Y-A9H1-01  58.0    STAGE I         0.17070
# 14  1/1/2027  TCGA-2Y-A9H5-01  59.0    STAGE I         0.16745
# 12  1/1/2026  TCGA-2Y-A9H3-01  45.0   STAGE II         0.16420
# 2   1/1/2021  TCGA-2Y-A9GT-01  51.0    STAGE I         0.06220
# ...

# %% [markdown]
# (i.e., two values before and one value after the missing value) to perform the interpolation.

# %%
# Quadratic interpolation
df.interpolate(method='quadratic')
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_7751/223136974.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='quadratic')
#          day        Sample ID   Age      Stage  Genome Altered  \
# 4   1/1/2022  TCGA-2Y-A9GV-01  54.0    STAGE I        0.092800
# 0   1/1/2020  TCGA-2V-A95S-01   NaN   STAGE II        0.204100
# 5   1/2/2022  TCGA-2Y-A9GW-01  64.0    STAGE I        0.147800
# 9   1/2/2024  TCGA-2Y-A9H0-01  49.0  STAGE III        0.203700
# 15  1/2/2027  TCGA-2Y-A9H6-01  68.0    STAGE I        0.231900
# 10  1/1/2025  TCGA-2Y-A9H1-01  58.0    STAGE I        0.170700
# 14  1/1/2027  TCGA-2Y-A9H5-01  59.0    STAGE I        0.320782
# 12  1/1/2026  TCGA-2Y-A9H3-01  45.0   STAGE II        0.164200
# 2   1/1/2021  TCGA-2Y-A9GT-01  51.0    STAGE I        0.062200
# ...

# %%
# Cubic interpolation
df.interpolate(method='cubic',limit_direction='both')
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_7751/3184272160.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='cubic',limit_direction='both')
#          day        Sample ID   Age      Stage  Genome Altered  \
# 4   1/1/2022  TCGA-2Y-A9GV-01  54.0    STAGE I        0.092800
# 0   1/1/2020  TCGA-2V-A95S-01   NaN   STAGE II        0.204100
# 5   1/2/2022  TCGA-2Y-A9GW-01  64.0    STAGE I        0.147800
# 9   1/2/2024  TCGA-2Y-A9H0-01  49.0  STAGE III        0.203700
# 15  1/2/2027  TCGA-2Y-A9H6-01  68.0    STAGE I        0.231900
# 10  1/1/2025  TCGA-2Y-A9H1-01  58.0    STAGE I        0.170700
# 14  1/1/2027  TCGA-2Y-A9H5-01  59.0    STAGE I        0.353361
# 12  1/1/2026  TCGA-2Y-A9H3-01  45.0   STAGE II        0.164200
# 2   1/1/2021  TCGA-2Y-A9GT-01  51.0    STAGE I        0.062200
# ...

# %%
df.interpolate(method='polynomial', order=5)
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_7751/4101450602.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='polynomial', order=5)
#          day        Sample ID   Age      Stage  Genome Altered  \
# 4   1/1/2022  TCGA-2Y-A9GV-01  54.0    STAGE I        0.092800
# 0   1/1/2020  TCGA-2V-A95S-01   NaN   STAGE II        0.204100
# 5   1/2/2022  TCGA-2Y-A9GW-01  64.0    STAGE I        0.147800
# 9   1/2/2024  TCGA-2Y-A9H0-01  49.0  STAGE III        0.203700
# 15  1/2/2027  TCGA-2Y-A9H6-01  68.0    STAGE I        0.231900
# 10  1/1/2025  TCGA-2Y-A9H1-01  58.0    STAGE I        0.170700
# 14  1/1/2027  TCGA-2Y-A9H5-01  59.0    STAGE I        0.476102
# 12  1/1/2026  TCGA-2Y-A9H3-01  45.0   STAGE II        0.164200
# 2   1/1/2021  TCGA-2Y-A9GT-01  51.0    STAGE I        0.062200
# ...

# %%
df.interpolate(method='spline',order=2)
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_7751/749626599.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='spline',order=2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.interpolate(method='spline',order=2)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
# ...

# %%
df.interpolate(method='cubicspline')
# Out:
# /var/folders/zt/c6nz838d225d1qv9vvq86p600000gn/T/ipykernel_96213/826477155.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='cubicspline')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.interpolate(method='cubicspline')
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
# ...
